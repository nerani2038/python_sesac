# %% [markdown]
# # EDA
#
# 목표: 데이터의 분포와 특성을 이해하고 분석 방향성을 설정하는 것

# %% [markdown]
# # 1.데이터 소개

# %% [markdown]
# ## 1.1 데이터의 종류
#
# <img src="./data/데이터 종류.png" alt="예제 이미지" width="900" height="300"> \ \
# 이미지 출처: https://double-d.tistory.com/23

# %% [markdown]
# ## 1.2 타이타닉 변수 설명
#
# - survived : 생존 여부 (0: 사망, 1: 생존) </br>
# - pclass : 승객 등급 (1: 1등급, 2: 2등급, 3: 3등급) </br>
# - name : 승객 이름 </br>
# - sex : 승객 성별 </br>
# - age : 승객 나이 </br>
# - sibsp : 함께 탑승한 형제/배우자 수 </br>
# - parch :	함께 탑승한 부모/자녀 수 </br>
# - ticket : 티켓 번호 </br>
# - fare : 승객이 지불한 요금 </br>
# - cabin : 객실 번호 </br>
# - embarked : 탑승 항구 (C: 셰르부르, Q: 퀸즈타운, S: 사우샘프턴) </br>

# %% [markdown]
# # 2. 시각화 차트 종류
#
# <img src="./data/시각화%20차트%20종류.png" alt="예제 이미지" width="700" height="500"> \
# 이미지 출처: https://yozm.wishket.com/magazine/detail/2406/
# \
# \
# <img src="./data/시각화 차트 종류 2.png" alt="예제 이미지" width="700" height="400">

# %% [markdown]
# ## 2.1 수치형 데이터 시각화
#
# ### 수치형 데이터 시각화
# - 히스토그램 : 수치형 데이터의 구간별 빈도수
# - 커널밀도추정 : 히스토그램을 매끄럽게 곡선으로 연결한 그래프
# - 분포도 : 수치형 데이터 하나의 분포를 나타내는 그래프
# - 러그 플롯 : 주변 분포를 나타내는 그래프
# ### 범주형 데이터 시각화
# - 막대 그래프 : 범주형 데이터 값에 따라 수치형 데이터 값이 어떻게 달라지는지 파악할 때 사용
# - 포인트 플롯 : 막대그래프와 모양만 다를 뿐 동일한 정보를 제공(여러 그래프를 비교할 때 가시성이 좋음)
# - 박스 플롯 : 막대그래프나 포인트 플롯보다 더 많은 정보를 제공(최솟값, 제1사분위 수, 제 2사분위 수, 제 3사분위 수, 최댓값) \
# <img src="./data/박스플롯.png" alt="예제 이미지" width="500" height="380">
#
# - 바이올린 플롯 : 박스플롯과 커널 밀도추정 함수 그래프를 합쳐놓은 그래프 \
# <img src="./data/바이올린플롯.png" alt="예제 이미지" width="500" height="380">
#
# - 카운트 플롯 : 범주형 데이터의 개수를 확인할 때 사용
# - 파이 그래프 : 범주형 데이터의 비율을 알아볼 때 사용
# ### 데이터 관계 시각화
# - 히트맵 : 데이터 간 관계를 색상으로 표현한 그래프
# - 라인 플롯 : 두 수치형 데이터 사이의 관계를 나타날 때 사용
# - 산점도 : 두 데이터의 관계를 점으로 표현하는 그래프
# - 산점도+회귀선 : 산점도와 선형 회귀선을 그려 전반적인 상관관계를 파악하기 좀 더 쉬움

# %% [markdown]
# # 3. 가설 설정 (타이타닉 영화를 기반으로)
#
# #### - 가설 1: 성별(Sex)이 생존률에 유의미한 영향을 미친다.
# 타이타닉 사고 당시, 여성의 생존율이 남성보다 훨씬 높았다는 것은 구조 우선 순위에서 여성에게 유리한 조건이 있었기 때문
#
# #### - 가설 2: 좌석 등급(Pclass)이 생존률에 유의미한 영향을 미친다.
# 높은 등급의 좌석에 위치한 승객들이 구조 우선 순위에서 더 유리한 조건에 있었을 수 있음
#
# #### - 가설 3: 나이(Age)가 생존률에 유의미한 영향을 미친다.
# 나이가 어린 승객들이 구조 우선 순위에서 더 유리한 위치에 있었을 수 있음
#
# #### - 가설 4: 운임(Fare)이 생존률에 유의미한 영향을 미친다.
# 더 높은 운임을 지불한 승객일수록 더 안전한 위치에 있었거나 구조될 가능성이 높았을 수 있음

# %% [markdown]
# # 4. 분석 과정
#
# 1. EDA (Exploratory Data Analysis)
# 2. 데이터 전처리 (Feature Engineering, Data Cleansing)
# 3. 데이터 모델링 (ML modeling) with 앙상블 기법
# 4. 모델 평가 (Model Evaluation)

# %% [markdown]
# # 5. EDA

# %% [markdown]
# ## 5.1 Package Import

# %%
# 필수 라이브러리 임포트
import numpy as np  # 수치 연산을 위한 라이브러리
import pandas as pd  # 데이터 조작 및 분석을 위한 라이브러리
import matplotlib.pyplot as plt  # 데이터 시각화를 위한 라이브러리
import seaborn as sns  # 고급 시각화를 위한 라이브러리 (Matplotlib 기반)

# 경고 메시지 무시 설정
import warnings
warnings.filterwarnings('ignore')  # 경고 메시지를 괄호 안에 입력

# %% [markdown]
# ## 5.2 titanic 불러오기

# %%
df = pd.read_csv('./data/titanic.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 5.3 데이터 탐색

# %% [markdown]
# ### 5.3.1 데이터 모양 확인

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 5.3.2 데이터 구조와 속성 확인
#
# - 종속변수에 영향을 미칠 / 미치지 않을 칼럼 확인
#     - 삭제할 칼럼 있는지 확인
# - 각 칼럼별로 데이터 타입 확인
#     - 모델링까지 할 경우 인코딩 및 정규화가 필요한 칼럼 확인
#     - 모델링을 하지 않더라도 시각화 및 통계분석을 원활히 하기 위해 해당 과정이 필요할 수도 있음

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 5.3.3 결측치 확인
# - Age, Cabin, Embarked에 결측치 존재
# - 결측치가 존재하는 변수들의 결측치 처리를 어떻게 할지 고민해보기
#     - 결측치 처리 방법 및 방향에 따라 생존 여부에 영향을 줄 수도 있음을 고려하기
#     - 결측치 개수가 적은 칼럼일 경우 -> 결측치가 존재하는 데이터(행)를 제거할지 말지 고려해보기
#     - 결측치 개수가 많을 경우 -> 결측치를 평균으로 채울지 중의값으로 채울지 고려해보기

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 5.3.4 데이터 통계 확인
#
# describe() 메서들르 통해 데이터의 분포, 범위, 중심 경향성 등을 빠르게 파악할 수 있다.
#
# 1. count
# - 설명: 해당 열에서 결측치가 아닌 데이터의 개수를 의미.
#
# 2. mean
# - 설명: 해당 열의 평균값.
# - 예시: Age의 평균값은 모든 나이의 합을 나눈 값으로, 중앙값이나 분포의 중심 경향성을 나타냄.
#
# 3. std (Standard Deviation, 표준편차)
# - 설명: 데이터가 평균을 기준으로 얼마나 퍼져 있는지를 나타냄.
# - 예시: Age의 표준편차가 크다면, 나이의 분포가 넓다는 뜻. 반대로 표준편차가 작다면 대부분의 나이가 평균에 가까운 값이라는 의미.
# - 추가설명: Age의 경우 나이대가 0~80 사이인데 표준편차가 14이면 분포가 굉장히 넓음을 의미
#
# 4. min
# - 설명: 해당 열에서의 최소값을 의미.
# - 예시: Fare의 최소값은 승객이 지불한 최소 요금을 나타냄.
#
# 5. 25% (1사분위수, Q1)
# - 설명: 데이터의 하위 25%가 해당 값 이하임을 의미.
# - 예시: Age의 1사분위수는 나이가 전체 데이터 중 하위 25%에 해당하는 승객의 나이를 의미.
#
# 6. 50% (중앙값, Q2 또는 Median)
# - 설명: 데이터의 중간값. 전체 데이터 중 50%가 해당 값 이하, 50%가 해당 값 이상임을 의미.
# - 예시: Age의 50% 값은 나이의 중앙값으로, 나이 분포의 중간을 나타냄.
#
# 7. 75% (3사분위수, Q3)
# - 설명: 데이터의 상위 25%가 해당 값 이상임을 의미.
# - 예시: Age의 3사분위수는 나이가 전체 데이터 중 상위 25%에 해당하는 승객의 나이를 의미.
#
# 8. max
# - 설명: 해당 열에서의 최댓값을 의미.
# - 예시: Fare의 최댓값은 승객이 지불한 가장 높은 요금을 나타냄.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## 5.4 종속변수(y) 탐색
# 타이타닉 데이터에서 종속변수(y)는 Survived다.

# %%
# 각 범주 별 데이터 개수 확인 -> 사망이 생존대비 60% 더 많음 
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import matplotlib.colors as mcolors 
import matplotlib.pyplot as plt
import seaborn as sns

# ------------------------------------스타일 설정------------------------------------
# Seaborn 스타일을 적용
sns.set_theme(style="whitegrid")

# 서브플롯 생성 : 하나의 figure에 여러개의 그래프(축,axes)를 배치하는 것
fig, ax = plt.subplots(1, 2, figsize=(18, 8)) # 1행 2열의 서브플롯 생성 

# 파이 차트 색상 설정
colors = ['#1f77b4', '#ff7f0e']  # 원하는 색상 목록

# ------------------------------------첫 번째 서브플롯: 원형차트(파이차트)------------------------------------
# Survived 컬럼에 대한 파이 차트 그리기
df['Survived'].value_counts().plot.pie(
    explode=[0, 0.1],  # 두 번째 파이 조각을 약간 분리
    autopct='%1.1f%%',  # 각 파이 조각의 비율을 표시
    ax=ax[0],  # 첫 번째 서브플롯에 그리기
    shadow=True,  # 그림자 효과 추가
    colors=colors  # 색상 설정
)

# 첫 번째 축에 제목 및 레이블 설정
ax[0].set_title('Survived')  # 차트 제목 설정
ax[0].set_ylabel('')  # y축 레이블 제거

# ------------------------------------두 번째 서브플롯: 막대 그래프------------------------------------
# 'Survived' 컬럼의 값들을 세어서 막대 그래프로 표현
sns.countplot(data=df, x='Survived', ax=ax[1], palette=colors)
ax[1].set_title('Survived')  # 차트 제목 설정

# 차트 출력
# plt.show() # -> 주피터에서는 필요없지만, 스크립트 환경에서는 해당 메서드가 필요
# Out:
# Text(0.5, 1.0, 'Survived')

# %% [markdown]
# (EDA) 약 62%가 Survived = 0 (사망), 38% 정도가 Survived = 1 (생존) 했음을 알 수 있다. </br>
#
# 참고로 Python의 포맷 문자열은 다음과 같이 표시한다. </br>
# %1.0f%%: 소수점 없이 정수 형태로 비율을 표시 (예: 20%) </br>
# %1.1f%%: 소수점 첫째 자리까지 비율을 표시 (예: 20.0%) </br>
# %1.2f%%: 소수점 둘째 자리까지 비율을 표시 (예: 20.00%) </br>
#
# 추가로, </br>
# 앞의 %는 포맷 문자열의 시작을 의미한다. </br>
# 뒤의 %%는 실제 기호 '5'를 표시한다. </br>

# %% [markdown]
# ## 5.5 독립 변수 탐색 및 변수별 관계성 탐색

# %% [markdown]
# ### 5.5.1 Pclass에 따른 생존율 확인
#
# Pclass는 순서형 변수이다.

# %%
# 클래스별 승객 수 -> 3등급이 가장 많음 
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# 클래스별 생존 빈도 수
df[['Pclass', 'Survived']].groupby('Pclass').value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
# 클래스 별 생존률 -> 어떤 요인이 1등급 승객의 생존율을 높였는지 생각해보기
df[['Pclass', 'Survived']].groupby('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 8))

# Seaborn 설정: 글꼴 크기 설정
# sns.set(font_scale=1)


# 첫 번째 서브플롯: Pclass별 승객 수 막대 그래프
sns.countplot(data=df, x='Pclass', hue='Pclass', ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass') 
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=0)
ax[0].set_ylabel('Count')  # y축 레이블 설정


# 두 번째 서브플롯: Pclass별 생존율
# 'Pclass' 컬럼을 기준으로 'Survived'를 색상 구분하여 막대 그래프로 표현
sns.barplot(data=df, x='Pclass', y='Survived', hue='Pclass', ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead')  # 차트 제목 설정
ax[1].set_xlabel('Pclass', fontsize=15) # sns.countplot에서는 fontsize를 직접 설정할 수 없음. 
                                        # 대신, Matplotlib의 텍스트 설정 함수를 사용

# 차트 표시
# plt.show()
# Out:
# Text(0.5, 0, 'Pclass')

# %% [markdown]
# 등급이 높을 수록 생존률이 높았음 -> 돈으로 목숨을 산 격

# %% [markdown]
# ### 5.5.2 Age는 연속형 변수

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# 첫 번째 서브플롯: Pclass와 Age에 따른 생존자와 사망자 분포 바이올린 플롯
sns.violinplot(
    data=df,
    x="Pclass",     
    y="Age",        
    hue='Survived',    
    split=True,     # 바이올린 플롯을 생존 여부에 따라 분할
    ax=ax[0]        
)
ax[0].set_title('Pclass and Age vs Survived')  
ax[0].set_yticks(range(0, 81, 10))  # y축 틱 설정

# 두 번째 서브플롯: Sex와 Age에 따른 생존자와 사망자 분포 바이올린 플롯
sns.violinplot(
    data=df,
    x='Sex',       
    y="Age",       
    hue="Survived",    
    split=True,    
    ax=ax[1]       
)
ax[1].set_title('Sex and Age vs Survived')  
ax[1].set_yticks(range(0, 81, 10))  # y축 틱 설정

# y축 범위 제한
ax[0].set_ylim(0, 80)
ax[1].set_ylim(0, 80)


# 차트 표시
plt.show()

# %% [markdown]
# ### 5.5.3 Embarked는 명목형 변수
#
# 오차막대: 각 데이터 포인트에서 신뢰구간이나 표준오차를 나타냄 (데이터의 변동성을 보여줌)
# - 오차 막대가 길수록 변동성이 크거나 샘플의 크기가 작을 수 있음
# - 데이터의 변동성이 크다: 데이터 값이 큰 폭으로 오르내리거나 불규칙적인 변화를 보이는 경우

# %%
# 항구별 생존율  
display(df[['Embarked', 'Survived']].groupby('Embarked').mean())
sns.catplot(x = 'Embarked', y = 'Survived', data = df, kind = 'point', height=4, aspect=1.2)
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
# 막대그래프로 각 데이터 표현 
f, ax = plt.subplots(2, 2, figsize=(20, 15))

# 첫 번째 서브플롯: 항구별 승객 수 
sns.countplot(x='Embarked', data=df, ax=ax[0, 0])
ax[0, 0].set_title('No. Of Passengers Boarded')

# 세 번째 서브플롯: 생존 여부에 따른 승객 수
sns.countplot(x='Embarked', hue='Survived', data=df, ax=ax[0, 1])
ax[0, 1].set_title('Embarked vs Survived')

# 두 번째 서브플롯: 성별에 따른 승객 수
sns.countplot(x='Embarked', hue='Sex', data=df, ax=ax[1, 0])
ax[1, 0].set_title('Male-Female Split for Embarked')

# 네 번째 서브플롯: 탑승 클래스에 따른 승객 수
sns.countplot(x='Embarked', hue='Pclass', data=df, ax=ax[1, 1])
ax[1, 1].set_title('Embarked vs Pclass')

# 서브플롯 간의 간격을 조정
plt.subplots_adjust(
    wspace=0.2,  # 서브플롯 간의 너비 간격 설정 (기본값보다 넓게 설정)
    hspace=0.5  # 서브플롯 간의 높이 간격 설정 (기본값보다 넓게 설정)
)

# %% [markdown]
# ### 5.5.4 SibSp는 이산형 변수
# SibSp: 함께 탑승한 형제/배우자 수

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[['SibSp', 'Survived']].groupby('SibSp').mean()
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
# 동행자수별 생존률

f, ax = plt.subplots(1,2,figsize = (20, 8))
 
sns.barplot(x= 'SibSp', y='Survived', data = df, ax = ax[0])
ax[0].set_title('SibSp vs Survived')

sns.pointplot(x='SibSp', y='Survived', data= df, ax = ax[1])
ax[1].set_title('SibSp vs Survived')

plt.show()

# %% [markdown]
# ### 5.5.5 Parch는 이산형 변수
#
# Parch: 함께 탑승한 부모/자녀 수

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df[['Parch', 'Survived']].groupby('Parch').mean()
# Out:
#        Survived
# Parch
# 0      0.343658
# 1      0.550847
# 2      0.500000
# 3      0.600000
# 4      0.000000
# 5      0.200000
# 6      0.000000

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))

sns.barplot(data=df, x='Parch', y='Survived', ax=ax[0])
ax[0].set_title('Parch vs Survived')

sns.pointplot(data=df, x='Parch', y='Survived', ax=ax[1])
ax[1].set_title('Parch vs Survived')

plt.show()

# %% [markdown]
# ### 5.5.6 Fare는 연속형 변수

# %%
# 요금에 따른 

f,ax=plt.subplots(1,3,figsize=(20,8))

# Pclass 1의 요금 분포를 히스토그램으로 표시
sns.histplot(df[df['Pclass'] == 1].Fare, ax=ax[0], kde=True)
ax[0].set_title('Fares in Pclass 1')

# Pclass 2의 요금 분포를 히스토그램으로 표시
sns.histplot(df[df['Pclass'] == 2].Fare, ax=ax[1], kde=True)
ax[1].set_title('Fares in Pclass 2')

# Pclass 3의 요금 분포를 히스토그램으로 표시
sns.histplot(df[df['Pclass'] == 3].Fare, ax=ax[2], kde=True)
ax[2].set_title('Fares in Pclass 3')

# plt.show()

# %% [markdown]
# ## 5.6 가설1 - Sex와 Survived의 관계

# %%
# 성별 생존 명수 확인 
df[['Sex', 'Survived']].groupby('Sex').value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
# 성별에 따른 생존한 승객 비율 
# 여성 중 74퍼 생존
# 남성 중 18퍼 생존  
df[['Sex', 'Survived']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

# 첫 번째 서브플롯: 성별에 따른 생존자와 사망자 수 막대그래프---------------------------
# hue : 'Sex' 컬럼을 기준으로 'Survived'를 색상 구분하여 막대 그래프로 표현
sns.countplot(data=df, x='Sex', hue='Survived', ax=ax[0])
ax[0].set_title('Sex: Survived vs Dead') 

# 두 번째 서브플롯: 성별에 따른 생존율 막대그래프------------------------------------
# 'Sex'와 'Survived' 컬럼을 그룹화하여 생존율의 평균을 계산하고 막대 그래프로 표현
sns.barplot(data=df, x='Sex', y='Survived', hue='Sex', palette='Set2', ax=ax[1])
ax[1].set_title('Survived vs Sex')  
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=0)  # x축 레이블을 가로로 설정

# plt.show()
# Out:
# [Text(0, 0, 'male'), Text(1, 0, 'female')]

# %% [markdown]
# ## 5.7 가설2 - Sex, Survived와 Pclass의 관계

# %%
# 성별에따른  클래스 별 승객 수 
df[['Sex', 'Pclass']].groupby(['Sex']).value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
# 성별에따른  클래스 별 승객의 생존율
df[['Sex', 'Pclass', 'Survived']].groupby(['Sex', 'Pclass']).mean()
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
# Catplot 생성: Pclass와 Survived 간의 관계를 성별(Sex)에 따라 구분하여 시각화
sns.catplot(
    data=df,       # 사용할 데이터프레임,
    x='Pclass',      # x축에 표시할 변수
    y='Survived',    # y축에 표시할 변수
    hue='Sex',       # 성별에 따라 다른 색상을 사용하여 구분
    kind='point'     # 점 그래프(point plot)로 표시
)

# 플롯 표시
# plt.show()

# %% [markdown]
# 먼저, Pclass와 Survived 모두 Categorical 데이터 이므로 catplot을 이용했다. </br>
#
# 위 Plot을 보면, 남 녀 모두 Pclass가 하등 객실로 감에따라 생존율이 떨어지는 것을 알 수 있다. </br>
#
# 특히 여자의경우 더욱 극적이다. </br>
#
# 물론 일단 여자의 경우 Lady/Baby First Policy에 의해 남자보다는 생존율이 압도적으로 높다. </br>
#
# 즉, 여자이면서 Pclass = 1에 머물렀을 경우 거의 모두 살아남았다고 할 수 있다. (여자 1등객실 94명중 3명만 사망했다고 한다) </br>
#
# 참고로, catplot(categorical plot) 함수는 다양한 그래프 유형을 지원하며, kind 파라미터를 통해 'point', 'bar', 'strip', 'swarm', 'box', 'violin' 등의 그래프를 생성할 수 있습니다.

# %% [markdown]
# ## 5.8 가설3 - Age와 Survived의 관계
#
# Age는 연속형 변수

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, 2, figsize=(16, 6))
x_sticts = list(range(0, 85, 5)) # x축에 표시되는 눈금 범위
y_sticks = list(range(0, 60, 10)) # y축에 표시되는 눈금 범위

# 첫 번째 서브플롯: 생존하지 못한 승객들의 나이 분포 히스토그램
sns.histplot(data=df[df['Survived']==0], x='Age', bins=20, edgecolor='black', color='red', ax=ax[0])

ax[0].set_title('Survived= 0')  # 첫 번째 서브플롯 제목 설정
ax[0].set_xticks(x_sticts) # 첫 번째 서브플롯의 x축 틱(그래프의 x축에 표시되는 눈금) 설정
ax[0].set_yticks(y_sticks) # 첫 번째 서브플롯의 y축 틱(그래프의 y축에 표시되는 눈금) 설정

# 두 번째 서브플롯: 생존한 승객들의 나이 분포 히스토그램
sns.histplot(data=df[df['Survived']==1], x='Age', bins=20, edgecolor='black', color='green', ax=ax[1])

ax[1].set_title('Survived= 1')    
ax[1].set_xticks(x_sticts)     
ax[1].set_yticks(y_sticks)      

# 플롯 표시
# plt.show()

# %% [markdown]
# 생존/사망 여부에 Frequency로 나타냈기때문에 20-40대 에서 분포가 비슷하다 할 수 있지만, </br>
# 영유아의 경우 생존할 가능성이 더 높았던것은 확실하다. </br>

# %% [markdown]
# ## 5.9 가설4 - Fare와 Survived의 관계

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, 2, figsize=(20, 10))
x_sticts = list(range(0, 550, 50))  
y_sticks = list(range(0, 500, 50)) 

# 첫 번째 서브플롯: 생존하지 못한 승객들의 요금 분포 히스토그램
sns.histplot(data=df[df['Survived']==0], x='Fare', bins=10, edgecolor='black', color='pink', ax=ax[0])

ax[0].set_title('Survived= 0') 
ax[0].set_xticks(x_sticts)      
ax[0].set_yticks(y_sticks)

# 두 번째 서브플롯: 생존한 승객들의 요금 분포 히스토그램
sns.histplot(data=df[df['Survived']==1], x='Fare', bins=15, edgecolor='black', color='blue', ax=ax[1])

ax[1].set_title('Survived= 1')      
ax[1].set_xticks(x_sticts) 
ax[1].set_yticks(y_sticks)        

# 플롯 표시
# plt.show()

# %% [markdown]
# # 6. EDA 결과 정리

# %% [markdown]
# - Sex: 남성에 비해 여성의 생존율은 매우 높았다.
#
# - Pclass: 일등석 승객이 되면 생존율이 높아지고, 삼등석은 생존율이 매우 낮았다.
#
# - Age: 영유아일 수록 생존 확률이 높았다, 15-35세사이의 승객이 많이 죽었다.
#
# - Embarked: Pclass1의 상당수가 S, Q에서 탑승했음에도 불구하고 C에서의 생존율이 높았다.
#
# - Parch + SibSp : 대가족이 혼자 여행하는 사람들보다 생존율이 올라갔다.
#
# - Fare : 요금을 많이 지불한 사람일수록, 생존율이 높았다.

# %%
# 숫자형 데이터만 선택하여 상관 행렬 계산
numeric_data = df.select_dtypes(include=['float64', 'int64'])

# 히트맵 생성: 상관 행렬을 시각화하고, 상관 계수 값을 표시
sns.heatmap(numeric_data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2) 
# numeric_data.corr() --> 상관 행렬을 계산
# annot=True --> 각 셀에 상관 계수 값을 표시 (annotation: 주석)
# cmap='RdYlGn' --> 색상 맵을 'Red-Yellow-Green'으로 설정
# linewidths=0.2 --> 셀 사이의 경계선 두께를 설정

# 현재 플롯의 Figure 객체 가져오기 
fig = plt.gcf() # 현재 생성되어 있는 Figure를 참조하거나 수정할 때 유용

# Figure 크기 설정
fig.set_size_inches(8, 6)

# 그래프 저장
# plt.savefig('./1st_correlation_heatmap.png', dpi=300, bbox_inches='tight')

# plt.show()

# %% [markdown]
# - 상관계수
#     - 양의 상관관계 : 한 변수가 증가하면 다른 변수도 증가
#     - 음의 상관관계 : 한 변수가 증가하면 다른 변수는 감소
