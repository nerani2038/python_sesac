# %%
import requests
from bs4 import BeautifulSoup
base_url = "http://www.goso.co.kr/bbs/board.php?bo_table=testDB&page="
all_titles = []
for page in range(1, 100):
    url = f"{base_url}{page}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue
    soup = BeautifulSoup(response.text, 'html.parser')
    for row in soup.select('tr'):
        category = row.select_one('.cate')
        title = row.select_one('.subject')
        if category and title and '여행' in category.text:
            all_titles.append(title.text.strip())
print(all_titles)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#       3 base_url = "http://www.goso.co.kr/bbs/board.php?bo_table=testDB&page="
#
# Cell In[8], line 1
# ----> 1 import requests
#       2 from bs4 import BeautifulSoup
#       3 base_url = "http://www.goso.co.kr/bbs/board.php?bo_table=testDB&page="
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import json
base_url = "http://www.goso.co.kr/bbs/board.php?bo_table=testDB&page="
result = []
for page in range(1, 21):
    url = f"{base_url}{page}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue
    soup = BeautifulSoup(response.text, 'html.parser')
    for row in soup.select('tr'):
        category = row.select_one('.cate')
        title = row.select_one('.subject')
        datetime = row.select_one('.datetime')
        company = row.select_one('.company')
        if category and title and '여행' in category.text:
            result.append(dict(
                title = title.text.strip(),
                category = category.text.strip(),
                datetime = datetime.text.strip(),
                company = company.text.strip()
            ))
# print(all_titles)

# json 저장
with open('prac_goso_01.json', 'w', encoding='utf-8') as json_file:
    json.dump(result, json_file, ensure_ascii=False)

# %%
import requests
from bs4 import BeautifulSoup
import json

base_url = "http://www.goso.co.kr/bbs/board.php?bo_table=testDB&page="
start_page = 1
end_page = 35000
step = 20

for batch_start in range(start_page, end_page + 1, step):
    batch_end = min(batch_start + step - 1, end_page)
    result = []

    for page in range(batch_start, batch_end + 1):
        url = f"{base_url}{page}"
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch page {page}")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        for row in soup.select('tr'):
            category = row.select_one('.cate')
            title = row.select_one('.subject')
            datetime = row.select_one('.datetime')
            company = row.select_one('.company')
            if category and title and '여행' in category.text:
                result.append(dict(
                    title=title.text.strip(),
                    category=category.text.strip(),
                    datetime=datetime.text.strip() if datetime else "",
                    company=company.text.strip() if company else ""
                ))

    # Save JSON for the current batch
    if result:
        json_filename = f"prac_goso_{batch_start}_{batch_end}.json"
        with open(json_filename, 'w', encoding='utf-8') as json_file:
            json.dump(result, json_file, ensure_ascii=False)
        print(f"Saved {len(result)} records to {json_filename}")
    else:
        print(f"No data found for pages {batch_start} to {batch_end}")
# Out:
# Saved 9 records to prac_goso_1_20.json
# Saved 17 records to prac_goso_21_40.json
# Saved 13 records to prac_goso_41_60.json
# Saved 14 records to prac_goso_61_80.json
# Saved 23 records to prac_goso_81_100.json
# Saved 10 records to prac_goso_101_120.json
# Saved 14 records to prac_goso_121_140.json
# Saved 13 records to prac_goso_141_160.json
# Saved 14 records to prac_goso_161_180.json
# Saved 13 records to prac_goso_181_200.json
# Saved 13 records to prac_goso_201_220.json
# Saved 15 records to prac_goso_221_240.json
# Saved 11 records to prac_goso_241_260.json
# Saved 14 records to prac_goso_261_280.json
# Saved 27 records to prac_goso_281_300.json
# Saved 23 records to prac_goso_301_320.json
# Saved 23 records to prac_goso_321_340.json
# Saved 13 records to prac_goso_341_360.json
# Saved 23 records to prac_goso_361_380.json
# Saved 15 records to prac_goso_381_400.json
# Saved 13 records to prac_goso_401_420.json
# Saved 16 records to prac_goso_421_440.json
# Saved 30 records to prac_goso_441_460.json
# Saved 20 records to prac_goso_461_480.json
# Saved 18 records to prac_goso_481_500.json
# Saved 16 records to prac_goso_501_520.json
# Saved 30 records to prac_goso_521_540.json
# Saved 15 records to prac_goso_541_560.json
# Saved 17 records to prac_goso_561_580.json
# Saved 11 records to prac_goso_581_600.json
# Saved 22 records to prac_goso_601_620.json
# Saved 14 records to prac_goso_621_640.json
# Saved 14 records to prac_goso_641_660.json
# Saved 9 records to prac_goso_661_680.json
# Saved 4 records to prac_goso_681_700.json
# Saved 9 records to prac_goso_701_720.json
# Saved 10 records to prac_goso_721_740.json
# Saved 8 records to prac_goso_741_760.json
# Saved 15 records to prac_goso_761_780.json
# Saved 14 records to prac_goso_781_800.json
# Saved 19 records to prac_goso_801_820.json
# Saved 10 records to prac_goso_821_840.json
# Saved 22 records to prac_goso_841_860.json
# Saved 8 records to prac_goso_861_880.json
# Saved 14 records to prac_goso_881_900.json
# Saved 24 records to prac_goso_901_920.json
# Saved 16 records to prac_goso_921_940.json
# Saved 11 records to prac_goso_941_960.json
# Saved 20 records to prac_goso_961_980.json
# Saved 19 records to prac_goso_981_1000.json
# Saved 17 records to prac_goso_1001_1020.json
# Saved 22 records to prac_goso_1021_1040.json
# Saved 18 records to prac_goso_1041_1060.json
# Saved 16 records to prac_goso_1061_1080.json
# Saved 18 records to prac_goso_1081_1100.json
# Saved 11 records to prac_goso_1101_1120.json
# Saved 16 records to prac_goso_1121_1140.json
# Saved 19 records to prac_goso_1141_1160.json
# Saved 18 records to prac_goso_1161_1180.json
# Saved 20 records to prac_goso_1181_1200.json
# Saved 17 records to prac_goso_1201_1220.json
# Saved 24 records to prac_goso_1221_1240.json
# Saved 6 records to prac_goso_1241_1260.json
# Saved 19 records to prac_goso_1261_1280.json
# Saved 13 records to prac_goso_1281_1300.json
# Saved 10 records to prac_goso_1301_1320.json
# Saved 12 records to prac_goso_1321_1340.json
# Saved 13 records to prac_goso_1341_1360.json
# Saved 11 records to prac_goso_1361_1380.json
# Saved 14 records to prac_goso_1381_1400.json
# Saved 12 records to prac_goso_1401_1420.json
# Saved 12 records to prac_goso_1421_1440.json
# Saved 16 records to prac_goso_1441_1460.json
# Saved 10 records to prac_goso_1461_1480.json
# Saved 14 records to prac_goso_1481_1500.json
# Saved 22 records to prac_goso_1501_1520.json
# Saved 11 records to prac_goso_1521_1540.json
# Saved 9 records to prac_goso_1541_1560.json
# Saved 13 records to prac_goso_1561_1580.json
# Saved 19 records to prac_goso_1581_1600.json
# Saved 16 records to prac_goso_1601_1620.json
# Saved 14 records to prac_goso_1621_1640.json
# Saved 16 records to prac_goso_1641_1660.json
# Saved 21 records to prac_goso_1661_1680.json
# Saved 19 records to prac_goso_1681_1700.json
# Saved 20 records to prac_goso_1701_1720.json
# Saved 14 records to prac_goso_1721_1740.json
# Saved 13 records to prac_goso_1741_1760.json
# Saved 18 records to prac_goso_1761_1780.json
# Saved 23 records to prac_goso_1781_1800.json
# Saved 18 records to prac_goso_1801_1820.json
# Saved 16 records to prac_goso_1821_1840.json
# Saved 20 records to prac_goso_1841_1860.json
# Saved 39 records to prac_goso_1861_1880.json
# Saved 33 records to prac_goso_1881_1900.json
# Saved 51 records to prac_goso_1901_1920.json
# Saved 44 records to prac_goso_1921_1940.json
# Saved 32 records to prac_goso_1941_1960.json
# Saved 31 records to prac_goso_1961_1980.json
# Saved 18 records to prac_goso_1981_2000.json
# Saved 15 records to prac_goso_2001_2020.json
# Saved 10 records to prac_goso_2021_2040.json
# Saved 18 records to prac_goso_2041_2060.json
# Saved 12 records to prac_goso_2061_2080.json
# Saved 10 records to prac_goso_2081_2100.json
# Saved 11 records to prac_goso_2101_2120.json
# Saved 15 records to prac_goso_2121_2140.json
# Saved 12 records to prac_goso_2141_2160.json
# Saved 9 records to prac_goso_2161_2180.json
# Saved 13 records to prac_goso_2181_2200.json
# Saved 16 records to prac_goso_2201_2220.json
# Saved 20 records to prac_goso_2221_2240.json
# Saved 17 records to prac_goso_2241_2260.json
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[6], line 16
#      14 for page in range(batch_start, batch_end + 1):
#      15     url = f"{base_url}{page}"
# ---> 16     response = requests.get(url)
#      17     if response.status_code != 200:
#      18         print(f"Failed to fetch page {page}")
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/homebrew/anaconda3/envs/sesac/lib/python3.10/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
import requests
from bs4 import BeautifulSoup
import json

base_url = "http://www.goso.co.kr/bbs/board.php?bo_table=testDB&page="
start_page = 2261
end_page = 35000
step = 20

for batch_start in range(start_page, end_page + 1, step):
    batch_end = min(batch_start + step - 1, end_page)
    result = []

    for page in range(batch_start, batch_end + 1):
        url = f"{base_url}{page}"
        response = requests.get(url)
        if response.status_code != 200:
            print(f"Failed to fetch page {page}")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        for row in soup.select('tr'):
            category = row.select_one('.cate')
            title = row.select_one('.subject')
            datetime = row.select_one('.datetime')
            company = row.select_one('.company')
            if category and title and '여행' in category.text:
                result.append(dict(
                    title=title.text.strip(),
                    category=category.text.strip(),
                    datetime=datetime.text.strip() if datetime else "",
                    company=company.text.strip() if company else ""
                ))

    # Save JSON for the current batch
    if result:
        json_filename = f"prac_goso_{batch_start}_{batch_end}.json"
        with open(json_filename, 'w', encoding='utf-8') as json_file:
            json.dump(result, json_file, ensure_ascii=False)
        print(f"Saved {len(result)} records to {json_filename}")
    else:
        print(f"No data found for pages {batch_start} to {batch_end}")
